# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv(r"D:\Python\Wipro\Melbourne_housing_FULL.csv")

# %%
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
#Structure of the dataset
dataset.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#Summary of the data
dataset.describe().transpose()
# Out:
#                  count          mean            std          min  \
# Rooms          34857.0  3.031012e+00       0.969933      1.00000
# Price          27247.0  1.050173e+06  641467.130105  85000.00000
# Distance       34856.0  1.118493e+01       6.788892      0.00000
# Postcode       34856.0  3.116063e+03     109.023903   3000.00000
# Bedroom2       26640.0  3.084647e+00       0.980690      0.00000
# Bathroom       26631.0  1.624798e+00       0.724212      0.00000
# Car            26129.0  1.728845e+00       1.010771      0.00000
# Landsize       23047.0  5.935990e+02    3398.841946      0.00000
# BuildingArea   13742.0  1.602564e+02     401.267060      0.00000
# YearBuilt      15551.0  1.965290e+03      37.328178   1196.00000
# Lattitude      26881.0 -3.781063e+01       0.090279    -38.19043
# Longtitude     26881.0  1.450019e+02       0.120169    144.42379
# Propertycount  34854.0  7.572888e+03    4428.090313     83.00000
#
# ...

# %%
dataset['Method'].unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %%
dataset['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria', nan], dtype=object)

# %%
"""
After understanding the data, the following are the different types of variables

1. Numeric attributes: All the ones except below columns (13)

2. Categorical attributes: Method,Type,RegionName,Suburb,Address,SellerG,CouncilArea(7) 

3. Date Attributes: Date (1)
"""
# Out:
# '\nAfter understanding the data, the following are the different types of variables\n\n1. Numeric attributes: All the ones except below columns (13)\n\n2. Categorical attributes: Method,Type,RegionName,Suburb,Address,SellerG,CouncilArea(7) \n\n3. Date Attributes: Date (1)\n'

# %% [markdown]
# ### Data cleaning ###

# %%
#Change Date column to right data type
dataset['Date']=pd.to_datetime(dataset['Date'])

# %%
#for cols in x:
#   dataset[cols]=dataset[cols].astype('category')

# %%
dataset.dtypes
# Out:
# Suburb                   object
# Address                  object
# Rooms                     int64
# Type                     object
# Price                   float64
# Method                   object
# SellerG                  object
# Date             datetime64[ns]
# Distance                float64
# Postcode                float64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea              object
# Lattitude               float64
# Longtitude              float64
# Regionname               object
# Propertycount           float64
# dtype: object

# %%
#Check for the duplicate entries and remove the rows
dataset.shape
# Out:
# (34857, 21)

# %%
# Rooms and Bedroom seems to hold the same data
dataset.drop(["Bedroom2"],axis=1,inplace=True)

# %%
dataset[dataset.duplicated()]
# Out:
#            Suburb        Address  Rooms Type  Price Method SellerG       Date  \
# 15858  Nunawading  1/7 Lilian St      3    t    NaN     SP  Jellis 2017-06-17
#
#        Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 15858      15.4    3131.0       3.0  2.0     405.0         226.0     2000.0
#
#                    CouncilArea  Lattitude  Longtitude            Regionname  \
# 15858  Manningham City Council  -37.82678   145.16777  Eastern Metropolitan
#
#        Propertycount
# 15858         4973.0

# %%
dataset.shape
# Out:
# (34857, 20)

# %%
#Drop the duplicates
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (34856, 20)

# %%
df=dataset.isna().any().to_frame()

# %% [markdown]
# ### Handling missing values ###

# %%
df.rename(columns={0: "Has NA?"})
# Out:
#                Has NA?
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
dataset['CouncilArea'].fillna('Unknown Area', inplace =True)

# %%
dataset.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          0
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# Dropping the missing values
dataset=dataset.dropna()

# %%
dataset.shape
# Out:
# (8887, 20)

# %%
dataset.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
import seaborn as sns

# %%
dataset=dataset[dataset['BuildingArea']!=0]

# %%
dataset.shape
# Out:
# (8842, 20)

# %% [markdown]
# ### Outlier treatment ###

# %%
dataset['Car'].describe()
# Out:
# count    8842.000000
# mean        1.691812
# std         0.976664
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max        10.000000
# Name: Car, dtype: float64

# %%
# Need to perform outlier analysis on variables that help in predicting the price of the house

# %%
def getOutlier(data):
    outliers=[]
    q3=data.quantile(0.75)
    q1=data.quantile(0.25)
    iqr=q3-q1
    outliers.append(q1-1.5*iqr)
    outliers.append(q3+1.5*iqr)
    return outliers

# %%
c1,c2=getOutlier(dataset['Car'])

# %%
d1,d2=getOutlier(dataset['Distance'])

# %%
l1,l2=getOutlier(dataset['Landsize'])

# %%
r1,r2=getOutlier(dataset['Rooms'])

# %%
sns.boxplot(dataset['Car'])

# %%
sns.boxplot(dataset['Distance'])

# %%
sns.boxplot(dataset['Landsize'])

# %%
sns.boxplot(dataset['Rooms'])

# %%
dataset['Landsize'].describe()
# Out:
# count     8842.000000
# mean       522.975458
# std       1062.597994
# min          0.000000
# 25%        211.000000
# 50%        477.000000
# 75%        652.000000
# max      42800.000000
# Name: Landsize, dtype: float64

# %%
#Getting the data without outliers
new_dataset=dataset.loc[((dataset['Car'] >= c1) & (dataset['Car'] <=c2 )) & ((dataset['Distance'] >= d1) & (dataset['Distance'] <=d2 )) 
           &((dataset['Landsize'] >= l1) & (dataset['Landsize'] <=l2 )) & ((dataset['Rooms'] >= r1) & (dataset['Rooms'] <=r2 ))]

# %%
new_dataset.shape
# Out:
# (7828, 20)

# %%
dataset.shape
# Out:
# (8842, 20)

# %%
#Verify for no outliers
sns.boxplot(new_dataset['Car'])

# %%
sns.distplot(new_dataset['Price'])

# %%
def FloorandCapOutliers(data):
    for col in data.columns:
        percentiles = data[col].quantile([0.01,0.99]).values
        data[col][data[col] <= percentiles[0]] = percentiles[0]
        data[col][data[col] >= percentiles[1]] = percentiles[1]

# %%
mydata=dataset.select_dtypes(['int64','float64'])

# %%
mydata.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 2           79.0     1900.0   -37.8079    144.9934         4019.0
# 4          150.0     1900.0   -37.8093    144.9944         4019.0
# 6          142.0     2014.0   -37.8072    144.9941         4019.0
# 11         210.0     1910.0   -37.8024    144.9993         4019.0
# 14         107.0     1890.0   -37.8060    144.9954         4019.0

# %%
FloorandCapOutliers(mydata)
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\pandas\core\generic.py:8767: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def appendExistingcols(data):
    x=np.array(dataset.columns)
    y=np.array(data.columns)
    for col in x:
        if(col not in y):
            data[col]=dataset[col]

# %%
#This has the value of outliers which are capped and floored and they are not removed
appendExistingcols(mydata)
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#mydata = has outliers changed to percentile values
#new_dataset = has outliers removed

# %%
plt.figure(figsize=(20,3))
sns.pairplot(mydata)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(mydata.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1, 'Variable Correlation')

# %%
#Study price vs Rooms
plt.scatter(mydata['Rooms'],mydata['Price'])

# %%
#Study price vs Bathroom
plt.scatter(mydata['Bathroom'],mydata['Price'])

# %%
#Study price vs Car
plt.scatter(mydata['Car'],mydata['Price'])

# %%
#Study price vs Rooms
plt.scatter(mydata['BuildingArea'],mydata['Price'])

# %%
mydata.drop(['Lattitude','Longtitude'],axis=1,inplace=True)
mydata.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Propertycount      Suburb          Address Type  \
# 2           79.0     1900.0         4019.0  Abbotsford  25 Bloomburg St    h
# 4          150.0     1900.0         4019.0  Abbotsford     5 Charles St    h
# 6          142.0     2014.0         4019.0  Abbotsford      55a Park St    h
# 11         210.0     1910.0         4019.0  Abbotsford     124 Yarra St    h
# 14         107.0     1890.0         4019.0  Abbotsford    98 Charles St    h
#
#    Method SellerG       Date         CouncilArea             Regionname
# ...

# %%
plt.figure(figsize=(10,2))
mydata.groupby(['Regionname','Type']).size().unstack().plot(kind="bar")

# %%
mydata.groupby(['Regionname']).size()
# Out:
# Regionname
# Eastern Metropolitan           979
# Eastern Victoria                51
# Northern Metropolitan         2589
# Northern Victoria               62
# South-Eastern Metropolitan     370
# Southern Metropolitan         2692
# Western Metropolitan          2056
# Western Victoria                43
# dtype: int64

# %%
final_data=mydata[(mydata['Regionname']=="Southern Metropolitan") | (mydata['Regionname']=="Northern Metropolitan") | (mydata['Regionname']=="Western Metropolitan")| (mydata['Regionname']=="Eastern Metropolitan")]

# %%
final_data['Property Age']=final_data['Date'].dt.year-final_data['YearBuilt']
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_data.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Propertycount      Suburb          Address Type  \
# 2           79.0     1900.0         4019.0  Abbotsford  25 Bloomburg St    h
# 4          150.0     1900.0         4019.0  Abbotsford     5 Charles St    h
# 6          142.0     2014.0         4019.0  Abbotsford      55a Park St    h
# 11         210.0     1910.0         4019.0  Abbotsford     124 Yarra St    h
# 14         107.0     1890.0         4019.0  Abbotsford    98 Charles St    h
#
#    Method SellerG       Date         CouncilArea             Regionname  \
# ...

# %%
final_data["Month Sold"]=final_data['Date'].dt.month
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_data.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Propertycount      Suburb          Address Type  \
# 2           79.0     1900.0         4019.0  Abbotsford  25 Bloomburg St    h
# 4          150.0     1900.0         4019.0  Abbotsford     5 Charles St    h
# 6          142.0     2014.0         4019.0  Abbotsford      55a Park St    h
# 11         210.0     1910.0         4019.0  Abbotsford     124 Yarra St    h
# 14         107.0     1890.0         4019.0  Abbotsford    98 Charles St    h
#
#    Method SellerG       Date         CouncilArea             Regionname  \
# ...

# %%
final_data.groupby(['Month Sold']).size().plot(marker="o",markerfacecolor="black",markersize=3)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(final_data.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Final Variable Correlation')
# Out:
# Text(0.5, 1, 'Final Variable Correlation')

# %%
final_data.dtypes
# Out:
# Rooms                     int64
# Price                   float64
# Distance                float64
# Postcode                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# Propertycount           float64
# Suburb                   object
# Address                  object
# Type                     object
# Method                   object
# SellerG                  object
# Date             datetime64[ns]
# CouncilArea              object
# Regionname               object
# Property Age            float64
# Month Sold                int64
# dtype: object

# %%
from sklearn import model_selection, preprocessing
for c in final_data.columns:
    if final_data[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(final_data[c].values)) 
        final_data[c] = lbl.transform(list(final_data[c].values))
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_data.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  Propertycount  Suburb  Address  Type  Method  \
# 2           79.0     1900.0         4019.0       0     3649     0       1
# 4          150.0     1900.0         4019.0       0     6026     0       3
# 6          142.0     2014.0         4019.0       0     6498     0       4
# 11         210.0     1910.0         4019.0       0     1285     0       1
# 14         107.0     1890.0         4019.0       0     8175     0       1
#
#     SellerG       Date  CouncilArea  Regionname  Property Age  Month Sold
# ...

# %% [markdown]
# ### Standardizing the data ###

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
Y=final_data.pop("Price")
Y=np.log(Y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-2828530de2c6> in <module>
# ----> 1 Y=final_data['Price']
#       2 Y=np.log(Y)
#
# ...

# %%
final_data.head()
final_data.drop(['Date'],axis=1,inplace=True)
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final_data, Y, test_size=0.33, random_state=42)

# %%
X_train[['Propertycount','Landsize','BuildingArea']]=scaler.fit_transform(X_train[['Propertycount','Landsize','BuildingArea']])
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
X_test[['Propertycount','Landsize','BuildingArea']]=scaler.fit_transform(X_test[['Propertycount','Landsize','BuildingArea']])
# Out:
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ravi Teja\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
final_data.shape
# Out:
# (8316, 18)

# %%
X_train
# Out:
#        Rooms  Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  \
# 18468      2      20.6    3064.0       1.0  1.0 -1.138362     -0.451119
# 13916      3       7.0    3013.0       1.0  2.0 -0.326257     -0.382901
# 17244      3       8.4    3072.0       1.0  2.0  0.588033     -0.246464
# 11208      3       9.8    3040.0       1.0  1.0  0.254586     -0.573912
# 31835      3      18.4    3029.0       1.0  5.0  0.666016      0.040053
# ...      ...       ...       ...       ...  ...       ...           ...
# 18913      3      20.6    3064.0       2.0  2.0 -0.035836      0.040053
# 17067      1       3.4    3031.0       1.0  1.0 -1.240547     -1.242452
# 17759      2       2.7    3141.0       1.0  1.0  1.115094     -1.160590
# 2686       3       7.8    3124.0       1.0  1.0  0.222317      0.176490
# 29248      5       7.9    3103.0       4.0  2.0  2.099300      2.263971
#
#        YearBuilt  Propertycount  Suburb  Address  Type  Method  SellerG  \
# ...

# %%
X_test.shape
# Out:
# (2745, 18)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=model.predict(X_test)

# %%
pred
# Out:
# array([14.61025143, 14.09926267, 13.38411128, ..., 13.84517123,
#        13.28818135, 13.50246449])

# %%
pred=np.exp2(model.predict(X_test))

# %%
realPrice=np.exp2(y_test)

# %%
res=realPrice-pred

# %%
res
# Out:
# 32038   -8041.956817
# 2292     4033.807010
# 31211    1606.654574
# 16776    -298.668887
# 7013     1131.242843
#             ...
# 2723    -1215.715623
# 23602   -1374.191105
# 29396     485.621472
# 9226     2079.139406
# 238      -795.672724
# Name: Price, Length: 2745, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(realPrice,pred)*100
# Out:
# 71.50592479918822

# %%
sns.distplot(res)
